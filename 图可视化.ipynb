# %%
import nxviz

# %%
from matplotlib import pyplot as plt

# %%
import networkx as nx

# %%
import os

# %%
import sys

# %%
sys.path.append(r"D:\Github\PyQt5\nxviz\examples")

# %%
os.chdir(r"D:\Github\PyQt5\nxviz\examples\geo")
import geo.divvy

# %%
os.chdir(r"D:\Github\PyQt5\nxviz\examples\arc")
import arc.barbell

# %%
import arc.edge_color

# %%
import arc.lollipop

# %%
import arc.node_size

# %%
import arc.octahedral

# %%
os.chdir(r"D:/Github/PyQt5/nxviz/examples/circos/")

# %%
import circos.barbell

# %%
import circos.change_font

# %%
import circos.edge_color

# %%
import circos.group_labels

# %%
import circos.group_order

# %%
os.chdir(r'D:\Github\PyQt5\nxviz\examples\datasets')
import importlib
importlib.reload(datasets.crime)
# Out:
# <module 'datasets.crime' from 'D:\\Github\\PyQt5\\nxviz\\examples\\datasets\\crime.py'>

# %%
import datasets.physician

# %%
os.chdir(r'D:\Github\PyQt5\nxviz\examples\geo')

# %%
import divvy
# Out:
# (5, {'name': 'State St & Harrison St', 'latitude': 41.87395806, 'longitude': -87.62773949, 'dpcapacity': 19, 'landmark': 30, 'online date': Timestamp('2013-06-28 00:00:00')})

# %%
os.chdir(r'D:/Github/PyQt5/nxviz/examples/matrix/')
import barbell

# %%
import lollipop

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('./pngs/stinkbug.png')

# %%
implot = plt.imshow(img)
lum_img = img[: ,:, 0]

# %%
lum_plot = plt.imshow(lum_img, cmap='hot')

# %%
lum_plot = plt.imshow(lum_img, cmap='nipy_spectral')
plt.colorbar()
